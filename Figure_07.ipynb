# %% [markdown]
# <a href="https://colab.research.google.com/github/borgesf/nicePythonPlots/blob/main/Figure_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
# This magic command ensures plots appear in the notebook

import numpy as np
import matplotlib.pyplot as plt

# Update global font settings (Helvetica instead of DejaVu Sans)
plt.rcParams.update({'font.family': 'DejaVu Sans', 'font.size': 12})

# Generate data for a circle
theta = np.linspace(0, 2 * np.pi, 100)
x = np.cos(theta)
y = np.sin(theta)

# Create a new figure for the plot
plt.figure(figsize=(7.5, 5))

# Plot the circle with a thicker line
plt.plot(x, y, 'k', linewidth=2, label='Circle')

# Set the plot title and axis labels with larger fonts for better readability
plt.title('Circle with Equal Axis Scaling', fontsize=16)
plt.xlabel('X-axis', fontsize=14)
plt.ylabel('Y-axis', fontsize=14)

# Get current Axes and lock equal aspect, then set limits
ax = plt.gca()
ax.set_aspect('equal', adjustable='box')
plt.xlim([-2, 2])
plt.ylim([-2, 2])

# Set y-ticks from -2 to 2
plt.yticks(np.arange(-2, 3, 1))

# Add grid, box, and legend
plt.grid(True)
ax = plt.gca()
for spine in ax.spines.values():
    spine.set_visible(True)
plt.legend(loc='lower left', fontsize=12)

# Show the figure
plt.show()
