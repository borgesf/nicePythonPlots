# %% [markdown]
# <a href="https://colab.research.google.com/github/borgesf/nicePythonPlots/blob/main/2025_03_09_Section_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
# This magic command ensures plots appear in the notebook

import numpy as np
import matplotlib.pyplot as plt

# Create an array of x values from 0 to 10 with an increment of 0.1
x = np.arange(0, 10.1, 0.1)

# Compute the sine and cosine values for each x
y1 = np.sin(x)
y2 = np.cos(x)

# Create a new figure
plt.figure()

# Plot sine and cosine curves
plt.plot(x, y1)
plt.plot(x, y2)

# Show the plot
plt.show()
